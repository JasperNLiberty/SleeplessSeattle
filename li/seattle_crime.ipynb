# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv('Seattle_Police_Department_911_Incident_Response.csv')
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2 = df[df['Initial Type Description'] != 'NaN']

# %%
df2.head()
# Out:
#   CAD CDW ID  CAD Event Number  General Offense Number  Event Clearance Code  \
# 0     ﻿15736       10000246357              2010246357                 242.0
# 1      15737       10000246471              2010246471                  65.0
# 2      15738       10000246255              2010246255                 250.0
# 3      15739       10000246473              2010246473                 460.0
# 4      15740       10000246330              2010246330                 250.0
#
#      Event Clearance Description       Event Clearance SubGroup  \
# 0              FIGHT DISTURBANCE                   DISTURBANCES
# 1          THEFT - MISCELLANEOUS                          THEFT
# 2  MISCHIEF, NUISANCE COMPLAINTS  NUISANCE, MISCHIEF COMPLAINTS
# 3     TRAFFIC (MOVING) VIOLATION          TRAFFIC RELATED CALLS
# 4  MISCHIEF, NUISANCE COMPLAINTS  NUISANCE, MISCHIEF COMPLAINTS
#
#    Event Clearance Group    Event Clearance Date  \
# 0           DISTURBANCES  07/17/2010 08:49:00 PM
# ...

# %%
list1 = df['Initial Type Description'].tolist()

# %%
len(list1)
# Out:
# 1326398

# %%
df2 = df[pd.notnull(df['Initial Type Description'])]

# %%
df2.shape
# Out:
# (729299, 19)

# %%
df3 = df.dropna()

# %%
df3.shape
# Out:
# (330699, 19)

# %%
df3['Event Clearance Description'].unique()
# Out:
# array(['TRESPASS', 'BURGLARY - RESIDENTIAL, UNOCCUPIED',
#        'MOTOR VEHICLE COLLISION',
#        'SUSPICIOUS CIRCUMSTANCES - BUILDING (OPEN DOOR, ETC.)',
#        'THEFT - CAR PROWL', 'DISTURBANCE, OTHER',
#        'FRAUD (INCLUDING IDENTITY THEFT)',
#        'PARKING VIOLATION (EXCEPT ABANDONED VEHICLES)',
#        'PERSON WITH A GUN', 'AUTO THEFT', 'THEFT - MISCELLANEOUS',
#        'PROPERTY DESTRUCTION', 'MISCHIEF, NUISANCE COMPLAINTS',
#        'SUSPICIOUS VEHICLE', 'AUTO RECOVERY', 'SUSPICIOUS PERSON',
#        'THEFT - AUTO ACCESSORIES', 'TRAFFIC (MOVING) VIOLATION',
#        'BURGLARY - COMMERCIAL', 'FELONY WARRANT SERVICE',
#        'PROPERTY - FOUND (FOLLOW UP TO SPD CASE)', 'ASSAULTS, OTHER',
#        'FORGERY, BAD CHECKS', 'CRISIS COMPLAINT - GENERAL',
#        'BURGLARY - UNOCCUPIED STRUCTURE ON RESIDENTIAL PROPERTY',
#        'FOUND PERSON', 'ARMED ROBBERY', 'HAZARDS',
#        'LICENSE PLATE THEFT OR LOSS', 'PROWLER', 'NARCOTICS, OTHER',
# ...

# %%
df3.head()
# Out:
#      CAD CDW ID  CAD Event Number  General Offense Number  \
# 255     1658031       16000028114               201628114
# 2146    1658050       16000028120               201628120
# 2375    1658053       16000028095               201628095
# 2432    1658054       16000028092               201628092
# 2443    1658055       16000028044               201628044
#
#       Event Clearance Code         Event Clearance Description  \
# 255                  161.0                            TRESPASS
# 2146                  50.0  BURGLARY - RESIDENTIAL, UNOCCUPIED
# 2375                 430.0             MOTOR VEHICLE COLLISION
# 2432                  50.0  BURGLARY - RESIDENTIAL, UNOCCUPIED
# 2443                 430.0             MOTOR VEHICLE COLLISION
#
#      Event Clearance SubGroup                  Event Clearance Group  \
# 255                  TRESPASS                               TRESPASS
# 2146   RESIDENTIAL BURGLARIES                               BURGLARY
# ...

# %%
df3
# Out:
#         CAD CDW ID  CAD Event Number  General Offense Number  \
# 255        1658031       16000028114               201628114
# 2146       1658050       16000028120               201628120
# 2375       1658053       16000028095               201628095
# 2432       1658054       16000028092               201628092
# 2443       1658055       16000028044               201628044
# 2551       1658056       16000027901               201627901
# 2758       1658062       16000028167               201628167
# 2807       1658064       16000028117               201628117
# 2913       1658066       16000028082               201628082
# 3113       1658067       16000024608               201624608
# 3139       1658068       16000022678               201622678
# 3261       1658072       16000028178               201628178
# 3486       1658075       16000028147               201628147
# 3608       1658076       16000027985               201627985
# ...

# %%
len(df3['Census Tract'].apply(lambda x: str(x)[0:4]).unique())
# Out:
# 128
